# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5e9c9998-4a9f-4b68-a020-412a855dd436" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e9c9998-4a9f-4b68-a020-412a855dd436">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os
with zipfile.ZipFile("/content/API_SP.POP.TOTL_DS2_en_csv_v2_403293 (1).zip",'r')as zip_ref:
  zip_ref.extractall("/content")

# %%
import os
for root,dirs,files in os.walk("/content"):
  for file in files:
    print(os.path.join(root,file))
# Out:
# /content/API_SP.POP.TOTL_DS2_en_csv_v2_403293.zip
# /content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_403293.csv
# /content/API_SP.POP.TOTL_DS2_en_csv_v2_403293 (1).zip
# /content/Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_403293.csv
# /content/API_SP.POP.TOTL_DS2_en_csv_v2_403293.csv
# /content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# /content/.config/.last_update_check.json
# /content/.config/gce
# /content/.config/.last_survey_prompt.yaml
# /content/.config/config_sentinel
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/active_config
# /content/.config/default_configs.db
# /content/.config/logs/2025.06.03/14.03.57.545879.log
# /content/.config/logs/2025.06.03/14.03.36.936842.log
# /content/.config/logs/2025.06.03/14.04.08.028368.log
# /content/.config/logs/2025.06.03/14.04.17.164872.log
# /content/.config/logs/2025.06.03/14.04.06.752874.log
# /content/.config/logs/2025.06.03/14.04.17.913789.log
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_403293.csv")
df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df['TableName'],bins=10,color='green',edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Age')
plt.title(' Age Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
gender_counts=df['Region'].value_counts()
gender_counts.plot(kind='bar',color='skyblue')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
